# %% [markdown]
# <a href="https://colab.research.google.com/github/kmotillo/face2face/blob/master/Algoritmos_AG1_Plantilla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad Guiada 1 de Algoritmos de Optimizacion
#
# Nombre: Victor Joel Pinargote
#
# https://colab.research.google.com/drive/1dOKyqJsrEibI4vCJlKkSYXUK_QVOrp0i?usp=sharing
#
#
# https://github.com/mi_usuario/03MAIR---Algoritmos-de-Optimizacion

# %% [markdown]
# ## Torres de Hanoi - Divide y venceras
#
# [Juego de Torres de Hanoi](https://uterra.com/juegos/torre_hanoi.php)

# %%
def Torres_Hanoi(N, desde, hasta):
  if N==1:
    print("Mover desde torre",desde,"hasta torre",hasta)
  else:
    Torres_Hanoi(N-1,desde,6-desde-hasta)
    print("Mover desde torre",desde,"hasta torre",hasta)
    Torres_Hanoi(N-1,6-desde-hasta, hasta)
#....

################################################################

# %% [markdown]
# Invocamos la función con los 3 parametros de entrada: `N = El nuemro de fichas` `desde = Torre inicial` y finalmente `hasta = torre destino`

# %%
Torres_Hanoi(4,1,3)
# Out:
# Mover desde torre 1 hasta torre 2
# Mover desde torre 1 hasta torre 3
# Mover desde torre 2 hasta torre 3
# Mover desde torre 1 hasta torre 2
# Mover desde torre 3 hasta torre 1
# Mover desde torre 3 hasta torre 2
# Mover desde torre 1 hasta torre 2
# Mover desde torre 1 hasta torre 3
# Mover desde torre 2 hasta torre 3
# Mover desde torre 2 hasta torre 1
# Mover desde torre 3 hasta torre 1
# Mover desde torre 2 hasta torre 3
# Mover desde torre 1 hasta torre 2
# Mover desde torre 1 hasta torre 3
# Mover desde torre 2 hasta torre 3

# %% [markdown]
# ## Cambio de monedas - Técnica voraz
# La presente función recive 2 valores: `cantidad = el valor a calcular` y `sistema = unidades de moneda disponibles`

# %%
def cambio_monedas(cantidad,sistema):
  print("SISTEMA:",sistema)
  solucion = [0 for i in range(len(sistema))]
  valor_acumulado = 0
 
  for i in range(len(sistema)):
    monedas = int((cantidad-valor_acumulado)/sistema[i])
    solucion[i] = monedas
    valor_acumulado += monedas*sistema[i]
    if valor_acumulado == cantidad: return solucion

  #return solucion

sistema = [25, 10, 5, 1]
cambio_monedas(27, sistema)

#....

################################################################
# Out:
# SISTEMA: [25, 10, 5, 1]
# [1, 0, 0, 2]

# %% [markdown]
# ## Implementación propia
# Basandome en el codigo explicado por el profesor, se modificó la lista solucion para ir acumulando las monedas mas no el indice. Cabe destacar que ambas soluciones son factibles y funcional exactamente igual.

# %%
def cambio_monedas(cantidad,sistema):
  print("SISTEMA:",sistema)
  solucion = []
  valor_acumulado = 0
  for i in range(len(sistema)):
    n_monedas = int((cantidad-valor_acumulado)/sistema[i])
    solucion.extend([sistema[i]]*n_monedas)
    valor_acumulado = sum(solucion)
    if valor_acumulado == cantidad: return solucion

  return solucion

sistema = [25, 10, 5, 1]
cambio_monedas(27, sistema)
# Out:
# SISTEMA: [25, 10, 5, 1]
# [25, 1, 1]

# %% [markdown]
# ## El presente algoritmo implementa la solucion para el problema de las N Reinas - Utiliando la técnica de `Backtraking`

# %%
#N Reinas - Vuelta Atrás()
################################################################################

#Verifica que en la solución parcial no hay amenzas entre reinas
################################################################
def es_prometedora(SOLUCION,etapa):
################################################################
  #print(SOLUCION)
  #Si la solución tiene dos valores iguales no es valida => Dos reinas en la misma fila
  for i in range(etapa+1):
    #print("El valor " + str(SOLUCION[i]) + " está " +  str(SOLUCION.count(SOLUCION[i])) + " veces")
    if SOLUCION.count(SOLUCION[i]) > 1:       
      return False
  
    #Verifica las diagonales
    for j in range(i+1, etapa +1 ):
      #print("Comprobando diagonal de " + str(i) + " y " + str(j))
      if abs(i-j) == abs(SOLUCION[i]-SOLUCION[j]) : return False
  return True

#Traduce la solución al tablero
################################################################
def escribe_solucion(S):
################################################################
  n = len(S)
  for x in range(n):
    print("")
    for i in range(n):
      if S[i] == x+1:
        print(" X " , end="")
      else:
        print(" - ", end="")



#Proceso principal de N-Reinas
################################################################
def reinas(N,solucion=[],etapa=0): 
################################################################


  if len(solucion) == 0:
    solucion=[0 for i in range(N)]

  #Recorremos todas las reinas
  for i in range(1, N+1):
    solucion[etapa] = i
    #print(solucion)
    if es_prometedora(solucion, etapa):
      if etapa == N-1:
        print("\n\nLa solución es:", solucion)
        escribe_solucion(solucion)
      else:
        reinas(N,solucion,etapa+1)
    else:
      None

    solucion[etapa] = 0
### ....

# %%
### Solución para un tablero con 4 reinas
N=4;etapa=0
solucion = [0 for i in range(N) ]
reinas(N,solucion,etapa)

### Solución para un tablero con 6 reinas
N=6;etapa=0
solucion = [0 for i in range(N) ]
reinas(N,solucion,etapa)

### Solución para un tablero con 8 reinas
N=8;etapa=0
solucion = [0 for i in range(N) ]
reinas(N,solucion,etapa)
# Out:
# La solución es: [2, 4, 1, 3]
#
#  -  -  X  -
#  X  -  -  -
#  -  -  -  X
#  -  X  -  -
#
# La solución es: [3, 1, 4, 2]
#
#  -  X  -  -
#  -  -  -  X
#  X  -  -  -
#  -  -  X  -
#
# La solución es: [2, 4, 6, 1, 3, 5]
#
#  -  -  -  X  -  -
#  X  -  -  -  -  -
#  -  -  -  -  X  -
#  -  X  -  -  -  -
#  -  -  -  -  -  X
#  -  -  X  -  -  -
#
# La solución es: [3, 6, 2, 5, 1, 4]
#
#  -  -  -  -  X  -
#  -  -  X  -  -  -
#  X  -  -  -  -  -
#  -  -  -  -  -  X
#  -  -  -  X  -  -
#  -  X  -  -  -  -
#
# La solución es: [4, 1, 5, 2, 6, 3]
#
#  -  X  -  -  -  -
#  -  -  -  X  -  -
#  -  -  -  -  -  X
#  X  -  -  -  -  -
#  -  -  X  -  -  -
#  -  -  -  -  X  -
#
# La solución es: [5, 3, 1, 6, 4, 2]
#
#  -  -  X  -  -  -
#  -  -  -  -  -  X
#  -  X  -  -  -  -
#  -  -  -  -  X  -
#  X  -  -  -  -  -
#  -  -  -  X  -  -
#
# La solución es: [1, 5, 8, 6, 3, 7, 2, 4]
#
#  X  -  -  -  -  -  -  -
#  -  -  -  -  -  -  X  -
#  -  -  -  -  X  -  -  -
#  -  -  -  -  -  -  -  X
# ...

# %% [markdown]
# ## El presente algoritmo implementa la solucion para el problema del `Viaje por el río` usando `Programación dinámica`

# %%
#Viaje por el rio - Programación dinámica
################################################################################

TARIFAS = [
[0,5,4,3,999,999,999],
[999,0,999,2,3,999,11],
[999,999, 0,1,999,4,10],
[999,999,999, 0,5,6,9],
[999,999, 999,999,0,999,4],
[999,999, 999,999,999,0,3],
[999,999,999,999,999,999,0]
]

#999 se puede sustituir por float("inf")


#Calculo de la matriz de PRECIOS y RUTAS
################################################################  
def Precios(TARIFAS):
################################################################  
  #Total de Nodos
  N = len(TARIFAS[0])
  
  #Inicialización de la tabla de precios
  PRECIOS = [ [9999]*N for i in [9999]*N]
  RUTA = [ [""]*N for i in [""]*N]
  
  for i in range(N-1):
    for j in range(i+1, N):
      MIN = TARIFAS[i][j]
      RUTA[i][j] = i
      
      for k in range(i, j):
        if PRECIOS[i][k] + TARIFAS[k][j] < MIN:
            MIN = min(MIN, PRECIOS[i][k] + TARIFAS[k][j] )
            RUTA[i][j] = k
        PRECIOS[i][j] = MIN
        
  return PRECIOS,RUTA 


PRECIOS, RUTA = Precios(TARIFAS)

# %% [markdown]
# ## Determinar la ruta con Recursividad Pythonic way

# %%
PRECIOS
# Out:
# [[9999, 5, 4, 3, 8, 8, 11],
#  [9999, 9999, 999, 2, 3, 8, 7],
#  [9999, 9999, 9999, 1, 6, 4, 7],
#  [9999, 9999, 9999, 9999, 5, 6, 9],
#  [9999, 9999, 9999, 9999, 9999, 999, 4],
#  [9999, 9999, 9999, 9999, 9999, 9999, 3],
#  [9999, 9999, 9999, 9999, 9999, 9999, 9999]]

# %%
RUTA
# Out:
# [['', 0, 0, 0, 1, 2, 5],
#  ['', '', 1, 1, 1, 3, 4],
#  ['', '', '', 2, 3, 2, 5],
#  ['', '', '', '', 3, 3, 3],
#  ['', '', '', '', '', 4, 4],
#  ['', '', '', '', '', '', 5],
#  ['', '', '', '', '', '', '']]

# %%
def calcular_ruta(RUTA, desde, hasta, ruta=[]):
  
  if desde == hasta:
    ruta.append(hasta)
    return ruta

  else:
    calcular_ruta(RUTA, desde, RUTA[desde][hasta], ruta)
    ruta.append(RUTA[desde][hasta])
    return ruta

# %% [markdown]
# ## Evaluar Rutas

# %%
PRECIOS,RUTA = Precios(TARIFAS)  

print("PRECIOS")
for i in range(len(TARIFAS)):
  print(PRECIOS[i])

print("\nRUTA")  
for i in range(len(TARIFAS)):
  print(RUTA[i]) 

print("\nLa ruta es:")  
calcular_ruta(RUTA, 0, 6, ruta=[])
# Out:
# PRECIOS
# [9999, 5, 4, 3, 8, 8, 11]
# [9999, 9999, 999, 2, 3, 8, 7]
# [9999, 9999, 9999, 1, 6, 4, 7]
# [9999, 9999, 9999, 9999, 5, 6, 9]
# [9999, 9999, 9999, 9999, 9999, 999, 4]
# [9999, 9999, 9999, 9999, 9999, 9999, 3]
# [9999, 9999, 9999, 9999, 9999, 9999, 9999]
#
# RUTA
# ['', 0, 0, 0, 1, 2, 5]
# ['', '', 1, 1, 1, 3, 4]
# ['', '', '', 2, 3, 2, 5]
# ['', '', '', '', 3, 3, 3]
# ['', '', '', '', '', 4, 4]
# ['', '', '', '', '', '', 5]
# ['', '', '', '', '', '', '']
#
# La ruta es:
# [0, 0, 2, 5]

# %% [markdown]
# # Implementacion con grafos

# %% [markdown]
# # Función para graficar el grafo

# %%
import networkx as nx
import matplotlib.pyplot as plt

def graficaRuta(grafo, ruta=[]):                         
  color_map = ['g', 'skyblue', 'r','pink', 'grey', 'purple','orange']
  new_path=nx.DiGraph()
  for i in range(len(path)-1):
    new_path.add_edge(path[i], path[i+1])

  labels = nx.get_edge_attributes(Grafo, "weight")
  layout = nx.spring_layout(Grafo)
  plt.figure(figsize=(10,10))
  nx.draw(new_path, pos=layout, edge_color='dodgerblue', font_size=15, width=3, with_labels=False, node_size=1000)
  nx.draw(Grafo,pos=layout, with_labels=True, node_size=1000, node_color=color_map)
  nx.draw_networkx_edge_labels(Grafo,pos=layout,edge_labels=labels)

  plt.show()

# %% [markdown]
# # Calculamos la Tabla de Precios y Rutas usando grafos

# %%
def PreciosGrafo(Grafo):
################################################################  
  
  #Total de Nodos
  N = len(Grafo.nodes())

  #Inicialización de la tabla de precios
  PRECIOS = [ [9999]*N for i in [9999]*N]
  RUTA = [ [""]*N for i in [""]*N]

  for i in Grafo.nodes():
    for j in range(i+1, N):
      MIN = Grafo.get_edge_data(i,j).get('weight') if Grafo.get_edge_data(i,j) else 9999
      RUTA[i][j] = i
      for k,l in Grafo[j].items():
          if PRECIOS[i][k] + Grafo[k][j].get('weight') < MIN:
            MIN = min(MIN, PRECIOS[i][k] + Grafo[k][j].get('weight'))
            RUTA[i][j] = k
          PRECIOS[i][j] = MIN
      
  return PRECIOS,RUTA

# %% [markdown]
# ## Construimos el Grafo a partir de la matriz de Tarifas

# %%
TARIFAS = [
[0,5,4,3,999,999,999],
[999,0,999,2,3,999,11],
[999,999, 0,1,999,4,10],
[999,999,999, 0,5,6,9],
[999,999, 999,999,0,999,4],
[999,999, 999,999,999,0,3],
[999,999,999,999,999,999,0]
]

Grafo=nx.Graph(create_using=nx.DiGraph)
[Grafo.add_node(i) for i in range(len(TARIFAS[0]))]
for i in range(len(TARIFAS[0])):
  #Grafo.add_node(i)
  for j in range(i+1,len(TARIFAS[i])):
    #Grafo.add_node(j)
    if(TARIFAS[i][j]!=999):
      Grafo.add_edge(i,j, weight=TARIFAS[i][j])

# Hacemos la llamada a la funcion que implementamos, la misma que recive el Grafo como entrada
PRECIOS,RUTA = PreciosGrafo(Grafo)


print("PRECIOS")
for i in range(len(TARIFAS)):
  print(PRECIOS[i])

print("\nRUTA")  
for i in range(len(TARIFAS)):
  print(RUTA[i]) 

print("\nLa ruta es:")  
calcular_ruta(RUTA, 0, 6, ruta=[])
# Out:
# PRECIOS
# [9999, 5, 4, 3, 8, 8, 11]
# [9999, 9999, 9999, 2, 3, 8, 7]
# [9999, 9999, 9999, 1, 6, 4, 7]
# [9999, 9999, 9999, 9999, 5, 6, 9]
# [9999, 9999, 9999, 9999, 9999, 9999, 4]
# [9999, 9999, 9999, 9999, 9999, 9999, 3]
# [9999, 9999, 9999, 9999, 9999, 9999, 9999]
#
# RUTA
# ['', 0, 0, 0, 1, 2, 5]
# ['', '', 1, 1, 1, 3, 4]
# ['', '', '', 2, 3, 2, 5]
# ['', '', '', '', 3, 3, 3]
# ['', '', '', '', '', 4, 4]
# ['', '', '', '', '', '', 5]
# ['', '', '', '', '', '', '']
#
# La ruta es:
# [0, 0, 2, 5]

# %% [markdown]
# # Graficamos el recorrido

# %%
inicio = 0
final = 6
path = calcular_ruta(RUTA, inicio, final, ruta=[])
path.append(final)
print("El coste del Recorrido es:",PRECIOS[inicio][final])
graficaRuta(Grafo, path)
# Out:
# El coste del Recorrido es: 11
